# %%
from random import randrange, uniform
import time
import pandas as pd
from pandas.io import sql
from sqlalchemy import create_engine
import urllib.request as urllib2
from datetime import datetime

# %%
def asd(API_POST_URL):
    try:
        now=datetime.now()
        tunti=now.hour
        
        engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}")
        
        if tunti >=1 and tunti <=6:

            satunnainenlämpö = uniform(5.0, 9.0)
            satunnainenkosteus = uniform(50, 55)
            
            lämpö=[]
            o = [float(satunnainenlämpö)]
            lämpö.extend(o)

            kosteus=[]
            k = [float(satunnainenkosteus)]
            kosteus.extend(k)

            d = {'Lämpötila':lämpö,'Ilmankosteus':kosteus}
            df = pd.DataFrame(d)
            df['Päivämääräys'] = datetime.strftime(datetime.now(), "%Y-%m-%d %H:%M:%S")            
            
            body = bytes(df.to_json(orient='records'), encoding='utf-8')
            req = urllib2.Request(REST_API_URL, body)
            response = urllib2.urlopen(req)
            
            df.to_sql(con=engine, name='lämpäkosteus', if_exists='append')


            
            print("Ilmanlämpötila " + str(satunnainenlämpö)+" °C")

            print("Ilmankosteus " + str(satunnainenkosteus) + " %")

            time.sleep(2)
            
        if tunti >6 and tunti <= 9:

            satunnainenlämpö = uniform(9.0, 14.0)
            satunnainenkosteus = uniform(55.0, 60.0)
            
            lämpö=[]
            o = [float(satunnainenlämpö)]
            lämpö.extend(o)

            kosteus=[]
            k = [float(satunnainenkosteus)]
            kosteus.extend(k)

            d = {'Lämpötila':lämpö,'Ilmankosteus':kosteus}
            df = pd.DataFrame(d)
           
            df['Päivämääräys'] = datetime.strftime(datetime.now(), "%Y-%m-%d %H:%M:%S")             
            body = bytes(df.to_json(orient='records'), encoding='utf-8')
            req = urllib2.Request(REST_API_URL, body)
            response = urllib2.urlopen(req)
            
            df.to_sql(con=engine, name='lämpäkosteus', if_exists='append')

            
            print("Ilmanlämpötila " + str(satunnainenlämpö)+" °C")

            print("Ilmankosteus " + str(satunnainenkosteus) + " %")

            time.sleep(2)

        if tunti >9 and tunti <= 12:
            satunnainenlämpö = uniform(13.0, 18.0)
            satunnainenkosteus = uniform(50.0, 40.0)
            
            lämpö=[]
            o = [float(satunnainenlämpö)]
            lämpö.extend(o)

            kosteus=[]
            k = [float(satunnainenkosteus)]
            kosteus.extend(k)

            d = {'Lämpötila':lämpö,'Ilmankosteus':kosteus}
            df = pd.DataFrame(d)
            df['Päivämääräys'] = datetime.strftime(datetime.now(), "%Y-%m-%d %H:%M:%S")             
            
            body = bytes(df.to_json(orient='records'), encoding='utf-8')
            req = urllib2.Request(REST_API_URL, body)
            response = urllib2.urlopen(req)
            
            df.to_sql(con=engine, name='lämpäkosteus', if_exists='append')

            
            print("Ilmanlämpötila " + str(satunnainenlämpö)+" °C")

            print("Ilmankosteus " + str(satunnainenkosteus) + " %")

            time.sleep(2)

        if tunti >12 and tunti <= 16:
            satunnainenlämpö = uniform(18.0, 25.0)
            satunnainenkosteus = uniform(40.0, 60.0)
            
            lämpö=[]
            o = [float(satunnainenlämpö)]
            lämpö.extend(o)

            kosteus=[]
            k = [float(satunnainenkosteus)]
            kosteus.extend(k)

            d = {'Lämpötila':lämpö,'Ilmankosteus':kosteus}
            df = pd.DataFrame(d)
            df['Päivämääräys'] = datetime.strftime(datetime.now(), "%Y-%m-%d %H:%M:%S")             
            
            body = bytes(df.to_json(orient='records'), encoding='utf-8')
            req = urllib2.Request(REST_API_URL, body)
            response = urllib2.urlopen(req)
            
            df.to_sql(con=engine, name='lämpäkosteus', if_exists='append')

            print("Ilmanlämpötila " + str(satunnainenlämpö)+" °C")

            print("Ilmankosteus " + str(satunnainenkosteus) + " %")

            time.sleep(2)
            
        if tunti >16 and tunti <= 19:
            satunnainenlämpö = uniform(20.0, 24.0)
            satunnainenkosteus = uniform(30.0, 40.0)

            lämpö=[]
            o = [float(satunnainenlämpö)]
            lämpö.extend(o)

            kosteus=[]
            k = [float(satunnainenkosteus)]
            kosteus.extend(k)

            d = {'Lämpötila':lämpö,'Ilmankosteus':kosteus}
            df = pd.DataFrame(d)
            df['Päivämääräys'] = datetime.strftime(datetime.now(), "%Y-%m-%d %H:%M:%S")             
            
            body = bytes(df.to_json(orient='records'), encoding='utf-8')
            req = urllib2.Request(REST_API_URL, body)
            response = urllib2.urlopen(req)
            
            df.to_sql(con=engine, name='lämpäkosteus', if_exists='append')

            print("Ilmanlämpötila " + str(satunnainenlämpö)+" °C")

            print("Ilmankosteus " + str(satunnainenkosteus) + " %")

            time.sleep(2)

        if tunti >19 and tunti <= 22:
            satunnainenlämpö = uniform(15.0, 18.0)
            satunnainenkosteus = uniform(25.0, 30.0)

            lämpö=[]
            o = [float(satunnainenlämpö)]
            lämpö.extend(o)

            kosteus=[]
            k = [float(satunnainenkosteus)]
            kosteus.extend(k)

            d = {'Lämpötila':lämpö,'Ilmankosteus':kosteus}
            df = pd.DataFrame(d)
            df['Päivämääräys'] = datetime.strftime(datetime.now(), "%Y-%m-%d %H:%M:%S")             
            
            body = bytes(df.to_json(orient='records'), encoding='utf-8')
            req = urllib2.Request(REST_API_URL, body)
            response = urllib2.urlopen(req)
            
            df.to_sql(con=engine, name='lämpäkosteus', if_exists='append')

            print("Ilmanlämpötila " + str(satunnainenlämpö)+" °C")

            print("Ilmankosteus " + str(satunnainenkosteus) + " %")

            time.sleep(2)

        if tunti >22 and tunti <= 24:
            
            satunnainenlämpö = uniform(8.0, 14.0)
            satunnainenkosteus = uniform(35.0, 36.0)

            lämpö=[]
            o = [float(satunnainenlämpö)]
            lämpö.extend(o)

            kosteus=[]
            k = [float(satunnainenkosteus)]
            kosteus.extend(k)

            d = {'Lämpötila':lämpö,'Ilmankosteus':kosteus}
            df = pd.DataFrame(d)
            df['Päivämääräys'] = datetime.strftime(datetime.now(), "%Y-%m-%d %H:%M:%S")             
            
            body = bytes(df.to_json(orient='records'), encoding='utf-8')
            req = urllib2.Request(REST_API_URL, body)
            response = urllib2.urlopen(req)
            
            df.to_sql(con=engine, name='lämpäkosteus', if_exists='append')

            
            print("Ilmanlämpötila " + str(satunnainenlämpö)+" °C")

            print("Ilmankosteus " + str(satunnainenkosteus) + " %")

            time.sleep(2)

# %%
if __name__ == '__main__':
    while True:
        REST_API_URL = "https://api.powerbi.com/beta/c850fe9c-b46c-4b2d-b863-01fa2a898068/datasets/ece49538-af55-43a0-91f4-84cfe4e5930c/rows?key=hDONIwQByhpiVcGjlrEwoVjGIE37amyFm4X2RgshfUdq6GFMKjOQCWl1WNO03dLY5RnyorO5Rq0nYU%2FAf63K2A%3D%3D"
        
        asd(REST_API_URL)
# Out:
# Ilmanlämpötila 23.261134985382988 °C
# Ilmankosteus 55.229591590548694 %
# Ilmanlämpötila 21.45308856322027 °C
# Ilmankosteus 41.84090328484747 %
# Ilmanlämpötila 24.954495462530534 °C
# Ilmankosteus 40.32721851799352 %
# Ilmanlämpötila 20.386472206900724 °C
# Ilmankosteus 40.913921661503515 %
# Ilmanlämpötila 22.428235848449006 °C
# Ilmankosteus 57.78041791285533 %
# Ilmanlämpötila 21.85980435248452 °C
# Ilmankosteus 58.09080918512052 %
# Ilmanlämpötila 24.68770482513643 °C
# Ilmankosteus 55.604116179864434 %
# Ilmanlämpötila 23.148705370929704 °C
# Ilmankosteus 59.52504173393193 %
# Ilmanlämpötila 19.508946043963423 °C
# Ilmankosteus 53.83076314598145 %
# Ilmanlämpötila 18.099885401892404 °C
# Ilmankosteus 44.23048306653293 %
# Ilmanlämpötila 24.815913479487808 °C
# Ilmankosteus 43.715178512704036 %
# Ilmanlämpötila 20.186665645747272 °C
# Ilmankosteus 56.47112323269424 %
# Ilmanlämpötila 23.05878179327366 °C
# Ilmankosteus 49.22271580000283 %
# ...
